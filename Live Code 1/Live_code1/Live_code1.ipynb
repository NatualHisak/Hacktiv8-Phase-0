# %% [markdown]
# <h1>INTRODUCTIONS</h1>
# <h2>Live Code 1 </h2>
# <h3><b>Muhamad Natual Hisak</b></h3>

# %% [markdown]
# <h2>PROBLEMS</h2>
# 1. Kamu adalah seorang data scientist yang bekerja di salah satu perusahaan manufaktur baterai Lithium ion. Tim produksi meminta kamu untuk mengecek apakah baterai yang mereka buat dalam kondisi bagus atau tidak. Sebelum melakukan pengecekan lebih lanjut, kamu diminta untuk menghitung hambatan/resistansi dan Daya setiap detik: <br>
#
# R=V/I<br>
#
# P=VI<br>
#
# R adalah Hambatan dalam satuan Ohm<br>
# P adalah Daya dalam Watt<br>
# I adalah kuat arus dalam satuan Ampere<br>
# V adalah tegangan dalam satuan Volt<br>

# %% [markdown]
# a. Buatlah dua fungsi eksplisit masing-masing memuat perhitungan hambatan (R) dan daya (P) yang nantinya akan digunakan untuk perhitungan

# %% [markdown]
# Import library yang digunakan yaitu pandas

# %%
import pandas as pd # import library pandas dan berikan alias 'pd'

# %% [markdown]
# load dataset dengan pd.read_excel("path") karena dataset berupa file excel

# %%
df = pd.read_excel(r'C:\Users\Omen\Desktop\batch_16\Live Code 1\Live_code1\NMC1-9.xlsx') #Load Dataset
df #tampilkan tabel
# Out:
#        time(s)    V_m  Current (A)  Cycle       Cap
# 0            0  4.098        0.997      1  2.840817
# 1            1  4.096        0.998      1  2.840817
# 2            2  4.094        0.999      1  2.840817
# 3            3  4.093        0.998      1  2.840817
# 4            4  4.092        0.999      1  2.840817
# ...        ...    ...          ...    ...       ...
# 90977    90977  2.506        1.002      9  2.770180
# 90978    90978  2.504        1.002      9  2.770180
# 90979    90979  2.502        1.002      9  2.770180
# 90980    90980  2.500        1.002      9  2.770180
# 90981    90981  2.497        1.002      9  2.770180
#
# [90982 rows x 5 columns]

# %% [markdown]
# buat fungsi perhitungan nilai R dan P dengan menggunakan def () :

# %%
def R(V,I) : #fungsi menghitung nilai R dengan input berupa nilai V dan I
    R = V/I #rumus hitung R
    return R #return nilai R 

def P(V,I) : #fungsi menghitung nilai P dengan input berupa nilai V dan I
    P = V*I #rumus hitung P
    return P #return nilai P

# %% [markdown]
# b. Buat kolom baru dengan nama kolom R/P berisikan hasil perhitungan daya/hambatan dengan kriteria untuk Kapasitas >=2.5 hitung daya, Kapasitas <2.5 hitung nilai hambatan. (Hint: Gunakan for loop dan if statement untuk mengerjakan perintah nomor b, kamu bisa menggunakan list untuk menyimpan perhitungan sementara, setelahnya dapat dimasukkan ke kolom R/P).

# %% [markdown]
# memasukkan nilai pada kolom V_m,Current (A), dan Cap kedalam list dan mendefine list kosong untuk hasil perhitungan

# %%
RP = [] #define list kosong dalam variabel RP sebagai tempat menampung value hasil hitung R atau P
V = df['V_m'].tolist() # ubah kolom V_m menjadi list
I = df['Current (A)'].tolist() # ubah kolom Current (A) menjadi list
C = df['Cap'].tolist()# ubah kolom Cap menjadi list

# %% [markdown]
# Memasukkan nilai hasil hitung R atau P kedalam list kosong dengan memanfaatkan loop dan conditional serta fungsi yang telah dibuat pada soal a

# %%
y=0 
z=0
for x in C : #For loop untuk menjalankan program tiap nilai pada kolom Cap
    if x>=2.5 : #conditional untuk nilai kapasitas lebih dari sama dengan 2.5
        RP.append(P(V[y],I[z])) #hitung nilai P dan hasilnya dimasukkan ke list RP
    elif x<2.5 :#conditional untuk nilai kapasitas kurang dari 2.5
        RP.append(R(V[y],I[z])) #hitung nilai R dan hasilnya dimasukkanke list RP
    y=y+1
    z=z+1
RP # tampilkan list RP yang sudah lengkap dengan value nya
# Out:
# [4.085706,
#  4.087808,
#  4.089906,
#  4.084814,
#  4.087908,
#  4.078727,
#  4.07364,
#  4.072644,
#  4.068555000000001,
#  4.06756,
#  4.071648,
#  4.070652,
#  4.073742,
#  4.077828,
#  4.081914,
#  4.085,
#  4.089085,
#  4.088083999999999,
#  4.088083999999999,
#  4.083,
#  4.083,
#  4.082,
#  4.073836,
#  4.072838,
#  4.064676,
#  4.06368,
#  4.06368,
#  4.06368,
#  4.066763,
#  4.066763,
#  4.070842,
#  4.079,
#  4.078,
#  4.086156,
#  4.082078,
#  4.085154,
#  4.077,
#  4.072923,
#  4.067848,
#  4.063771999999999,
#  4.0587,
#  4.0587,
#  4.0587,
#  4.057704,
#  4.065852,
#  4.069926,
#  4.074,
#  4.078073999999999,
#  4.077073,
#  4.077073,
#  4.081146,
#  4.077073,
#  4.076072,
#  4.067928,
#  4.063856,
#  4.058787,
#  4.054716,
#  4.05372,
#  4.05372,
#  4.05372,
#  4.057790000000001,
#  4.06186,
#  4.064931,
#  4.073068999999999,
#  4.073068999999999,
#  4.073068999999999,
#  4.073068999999999,
#  4.068,
#  4.068,
#  4.063931999999999,
#  4.059863999999999,
#  4.054799,
# ...

# %% [markdown]
# Copy dataframe df ke dalam variabel baru

# %%
new_df = df.copy() #copy df kedalam variabel new_df
new_df #tampilkan tabel hasil copy yang ada pada variabel new_df
# Out:
#        time(s)    V_m  Current (A)  Cycle       Cap
# 0            0  4.098        0.997      1  2.840817
# 1            1  4.096        0.998      1  2.840817
# 2            2  4.094        0.999      1  2.840817
# 3            3  4.093        0.998      1  2.840817
# 4            4  4.092        0.999      1  2.840817
# ...        ...    ...          ...    ...       ...
# 90977    90977  2.506        1.002      9  2.770180
# 90978    90978  2.504        1.002      9  2.770180
# 90979    90979  2.502        1.002      9  2.770180
# 90980    90980  2.500        1.002      9  2.770180
# 90981    90981  2.497        1.002      9  2.770180
#
# [90982 rows x 5 columns]

# %% [markdown]
# Tambahkan kolom baru berdasarkan list RP yang telah dibuat

# %%
new_df["R/P"]=RP #buat kolom baru bernama R/P dengan isi berupa value pada list RP
new_df #tampilkan tabel setelah ditambahkan kolom baru
# Out:
#        time(s)    V_m  Current (A)  Cycle       Cap       R/P
# 0            0  4.098        0.997      1  2.840817  4.085706
# 1            1  4.096        0.998      1  2.840817  4.087808
# 2            2  4.094        0.999      1  2.840817  4.089906
# 3            3  4.093        0.998      1  2.840817  4.084814
# 4            4  4.092        0.999      1  2.840817  4.087908
# ...        ...    ...          ...    ...       ...       ...
# 90977    90977  2.506        1.002      9  2.770180  2.511012
# 90978    90978  2.504        1.002      9  2.770180  2.509008
# 90979    90979  2.502        1.002      9  2.770180  2.507004
# 90980    90980  2.500        1.002      9  2.770180  2.505000
# 90981    90981  2.497        1.002      9  2.770180  2.501994
#
# [90982 rows x 6 columns]

# %% [markdown]
# c. Hitunglah rata-rata nilai kapasitas untuk arus = 1 Ampere dan cycle ganjil.

# %% [markdown]
# Mengambil data tabel dengan kondisi ((Current(A)= 1) & (Cycle%2=1))

# %%
avg = new_df[(new_df['Current (A)'] == 1) & (new_df['Cycle']%2 == 1)] #mengambil data tabel dengan kondisi ((Current(A)= 1) & (Cycle%2=1))
avg #tampilkan hasilnya
# Out:
#        time(s)    V_m  Current (A)  Cycle       Cap    R/P
# 15          15  4.085          1.0      1  2.840817  4.085
# 19          19  4.083          1.0      1  2.840817  4.083
# 20          20  4.083          1.0      1  2.840817  4.083
# 21          21  4.082          1.0      1  2.840817  4.082
# 31          31  4.079          1.0      1  2.840817  4.079
# ...        ...    ...          ...    ...       ...    ...
# 90909    90909  2.640          1.0      9  2.770180  2.640
# 90923    90923  2.615          1.0      9  2.770180  2.615
# 90937    90937  2.589          1.0      9  2.770180  2.589
# 90949    90949  2.565          1.0      9  2.770180  2.565
# 90967    90967  2.528          1.0      9  2.770180  2.528
#
# [6830 rows x 6 columns]

# %% [markdown]
# Mencari nilai rata-rata pada kolom Cap berdasarkan tabel avg diatas

# %%
avgvalue = avg['Cap'].mean() #Menghitung rata-rata nilai dari tabel Cap
print(avgvalue) # Print hasilnya
# Out:
# 2.8064845553927484
