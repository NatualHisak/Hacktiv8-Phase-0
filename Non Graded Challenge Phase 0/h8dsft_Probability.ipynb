# %% [markdown]
# <h1>NON GRADED CHALLENGE 9</h1>

# %% [markdown]
# Buatlah sebuah kode untuk mensimulasikan melempar koin sebanyak 50.000 kali dengan assign value random berupa 0 dan 1 untuk kepala atau ekor. Setiap kali koin dilempar, peluang untuk mendapatkan kepala atau ekor adalah 50%.

# %%
#import library
import random
import matplotlib.pyplot as plt

#Variabel jumlah lemparan dan total head/tail
throw = 50000
head = 0
tail = 0

#Loop untuk menghitung jumlah terjadinya head/tail tiap lemparan
for throw in range(0, throw):
  result = random.randint(0, 1)
  if result == 0:
    head += 1
  else:
    tail += 1

print(head, tail)
# Out:
# 24968 25032

# %% [markdown]
# Plot

# %%
#plot
plt.figure(figsize=(10, 10))
plt.pie([head_count, tail_count], labels=['Head', 'Tail'])
plt.legend()
plt.show()
